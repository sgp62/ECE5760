# %%
import numpy as np

import pandas as pd
df=pd.read_csv('ECE5760/FinalProject/17x17Serial.csv', sep=',',header=None)

z_flat = np.array([df[4].values[3:]])

[x,y]=np.meshgrid(np.linspace(0,16,num=17),np.linspace(0,16,num=17));

#z = np.array([[df[4].values[4+i*17:22+i*17]] for i in range(17)],dtype=object)
#print(z[0])
#print(z.shape)
# z = np.array([
# [187,	214,	207,	202,	190,     203,	222,	215,	187],
# [205,	197,	209,	197,	209,	197,	213,	197,	201],
# [207,	209,	190,	198,	207,	197,	190,	208,	192],
# [203,	188,	206,	188,	218,	188,	207,	188,	197],
# [167,	208,	207,	199,	227,	197,	211,	209,	156],
# [201,	196,	210,	196,	216,	196,	211,	196,	196],
# [209,	214,	207,	204,	208,	204,	207,	216,	202],
# [219,	214,	210,	214,	208,	214,	210,	214,	219],
# [238,	217,	207,	205,	193,	205,	207,	217,	238]
# ])

x_flat = np.matrix.flatten(x); #Gridded longitude
y_flat = np.matrix.flatten(y); #Gridded latitude

#z_flat = np.matrix.flatten(z)/np.max(z) * 255; #Gridded elevation

import matplotlib.pyplot as plt
plt.scatter(x_flat,y_flat,600,z_flat, marker="s")
plt.colorbar(label='Elevation above sea level [m]')
plt.xlabel('Longitude [°]')
plt.ylabel('Latitude [°]')

plt.show() 



# show hight map in 3d
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z)
ax.set_zlim(0,255)
plt.title('z as 3d height map')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-80d238231b0d> in <module>
#      41 fig = plt.figure()
#      42 ax = fig.add_subplot(111, projection='3d')
# ---> 43 ax.plot_surface(x, y, z)
#      44 ax.set_zlim(0,255)
#      45 plt.title('z as 3d height map')
#
# c:\programdata\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1555         if Z.ndim != 2:
#    1556             raise ValueError("Argument Z must be 2-dimensional.")
# -> 1557         if np.any(np.isnan(Z)):
#    1558             cbook._warn_external(
#    1559                 "Z contains NaN values. This may result in rendering "
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
